# %% [markdown]
# ## Ejercicio 1 ##

# %% [markdown]
# ## Ejercicio 2 ##

# %% [markdown]
# ## Ejercicio 3 ##

# %% [markdown]
# ## Ejercicio 4 ##

# %% [markdown]
# ## Ejercicio 5 ##

# %% [markdown]
# ## Ejercicio 6 ##
